# %%
import pandas as pd

df = pd.read_csv('healthcare_dataset.csv') 
df.head()
# Out:
#    PatientID  Age  Gender   BMI  BloodPressure      Condition  RiskScore  \
# 0          1   56  Female  20.9             94   Hypertension       10.3
# 1          2   69  Female  39.3            101   Hypertension       15.5
# 2          3   46    Male  33.7            135  Heart Disease       13.2
# 3          4   32  Female  18.9            123       Diabetes        7.6
# 4          5   60    Male  26.8            138   Hypertension       13.1
#
#    HighRisk
# 0         0
# 1         1
# 2         1
# 3         0
# 4         1

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PatientID      300 non-null    int64
#  1   Age            300 non-null    int64
#  2   Gender         300 non-null    object
#  3   BMI            300 non-null    float64
#  4   BloodPressure  300 non-null    int64
#  5   Condition      238 non-null    object
#  6   RiskScore      300 non-null    float64
#  7   HighRisk       300 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 18.9+ KB
# PatientID         0
# Age               0
# Gender            0
# BMI               0
# BloodPressure     0
# Condition        62
# RiskScore         0
# HighRisk          0
# dtype: int64

# %%
# Age groups
bins = [0, 30, 45, 60, 100]
labels = ['Young' , 'Middle', 'Senior', 'Elderly']
df['Age_Group'] = pd.cut(df['Age'], bins = bins , labels = labels)

# %%
df.head()
# Out:
#    PatientID  Age  Gender   BMI  BloodPressure      Condition  RiskScore  \
# 0          1   56  Female  20.9             94   Hypertension       10.3
# 1          2   69  Female  39.3            101   Hypertension       15.5
# 2          3   46    Male  33.7            135  Heart Disease       13.2
# 3          4   32  Female  18.9            123       Diabetes        7.6
# 4          5   60    Male  26.8            138   Hypertension       13.1
#
#    HighRisk Age_Group
# 0         0    Senior
# 1         1   Elderly
# 2         1    Senior
# 3         0    Middle
# 4         1    Senior

# %%
# Total patients
total = len(df)
print("Toal Patient: ",total)
# Out:
# 300

# %%
# avg rige
avg_age = df['Age'].mean()
print('Avg Age : ',avg_age)
# Out:
# Avg Age :  50.00666666666667

# %%
# avg risk score
avg_risk = df['RiskScore'].mean()
print("Avg Risk Score :",avg_risk)
# Out:
# Avg Risk Score : 12.115333333333334

# %%
import matplotlib.pyplot as plt 
plt.scatter(df['Age'] , df['RiskScore'])
plt.xlabel("Age")
plt.ylabel("Risk Score")
plt.title("Risk Analysis")
plt.show()

# %%
df['Condition'].value_counts().plot(kind = "bar")
plt.title("Top Medical Conditions")
plt.show()

# %%
df.to_csv("cleaned_heathcare_data.csv" , index = False)
